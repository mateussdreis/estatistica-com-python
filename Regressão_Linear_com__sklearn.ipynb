# %% [markdown]
# <a href="https://colab.research.google.com/github/mateussdreis/estatistica-com-python/blob/main/Regressa%CC%83o_Linear_com__sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dados_imoveis = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Projeto dados/estatistica/Aula 03/exercicio_imoveis.csv', engine='python', sep=';', decimal=",")
display(dados_imoveis)
# Out:
#     area    valor
# 0    128  9626.80
# 1    114  6754.39
# 2     73  5753.42
# 3     92  6141.30
# 4     96  9052.08
# 5     91  7582.42
# 6    107  8224.30
# 7     83  8012.05
# 8     97  8402.06
# 9    112  7946.43
# 10    97  8453.61
# 11   114  6833.33
# 12    83  5409.64
# 13   114  8245.61
# 14   140  9992.86
# 15   112  8750.00
# 16   114  6833.33
# 17   133  8195.49
# 18   127  8267.72
# 19    98  8775.51
# 20   119  7394.96
# 21    98  9285.71
# 22    92  6195.65
# 23    95  9105.26
# 24   106  9245.28
# 25    96  8020.83
# 26    97  8402.06
# 27   107  7897.20
# 28   110  8636.36
# 29   104  8173.08

# %%
plt.figure()
plt.scatter(dados_imoveis['area'], dados_imoveis['valor'])
plt.xlabel('Área do Imóvel')
plt.ylabel('Valor por metro quadrado')
plt.title('Dispersão dos dados')
plt.show()

# %%
# Bibliotecas necessárias para fazer a regressão
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
X = dados_imoveis['area'].values

y = dados_imoveis['valor'].values

# %%
X.shape # verificando o formato
# Out:
# (30,)

# %%
X = X.reshape(-1,1)
X.shape
# Out:
# (30, 1)

# %%
y.shape # verificando o formato da variável
# Out:
# (30,)

# %%
y = y.reshape(-1,1) # refazendo de maneira a ficar compatível com o modelo

# %%
from sklearn.model_selection import train_test_split #biblioteca para fazer a validação cruzada

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) #separando em variáveis de teste e de treino

# %%
regressor = LinearRegression() # criando o modelo

regressor.fit(X_train, y_train) # treinando o modelo
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [[6998.31367861]
#  [8058.03399535]
#  [8172.59835392]
#  [7685.69983001]
#  [7685.69983001]
#  [7943.46963679]]

# %%
plt.scatter(X_train, y_train,color='r')

plt.plot(X_test, y_pred,color='k')



plt.show()

# %%
dados_imoveis.cov()
# Out:
#              area         valor
# area    232.86092  7.803393e+03
# valor  7803.39269  1.303079e+06

# %%
dados_imoveis.corr()
# Out:
#            area     valor
# area   1.000000  0.447971
# valor  0.447971  1.000000

# %%
from sklearn.linear_model import LinearRegression
# Creating a Linear Regression model on our data
lin = LinearRegression()
lin.fit(dados_imoveis[['area']], dados_imoveis['valor'])
# Creating a plot
ax = dados_imoveis.plot.scatter(x='area', y='valor', c='k')
ax.plot(dados_imoveis[['area']], lin.predict(dados_imoveis[['area']]), c='r')

# %% [markdown]
# O coeficiente R quadrado de pearson é o quadrado da correlação

# %%
lin.score(dados_imoveis[['area']], dados_imoveis['valor'])
# Out:
# 0.2006778341299611
